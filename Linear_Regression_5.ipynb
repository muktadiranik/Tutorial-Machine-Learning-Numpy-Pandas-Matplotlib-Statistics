# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('canada_per_capita_income.csv')
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
plt.scatter(df['year'], df['per capita income (US$)'], marker='.', color='black')
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.title('canada_per_capita_income')
# Out:
# Text(0.5, 1.0, 'canada_per_capita_income')

# %%
x = df[['year']]
y = df['per capita income (US$)']

# %%
x, y
# Out:
# (    year
#  0   1970
#  1   1971
#  2   1972
#  3   1973
#  4   1974
#  5   1975
#  6   1976
#  7   1977
#  8   1978
#  9   1979
#  10  1980
#  11  1981
#  12  1982
#  13  1983
#  14  1984
#  15  1985
#  16  1986
#  17  1987
#  18  1988
#  19  1989
#  20  1990
#  21  1991
#  22  1992
#  23  1993
#  24  1994
#  25  1995
#  26  1996
#  27  1997
#  28  1998
#  29  1999
#  30  2000
#  31  2001
#  32  2002
#  33  2003
#  34  2004
#  35  2005
#  36  2006
#  37  2007
#  38  2008
#  39  2009
#  40  2010
#  41  2011
#  42  2012
#  43  2013
#  44  2014
#  45  2015
#  46  2016,
#  0      3399.299037
#  1      3768.297935
#  2      4251.175484
#  3      4804.463248
#  4      5576.514583
#  5      5998.144346
#  6      7062.131392
#  7      7100.126170
#  8      7247.967035
#  9      7602.912681
#  10     8355.968120
#  11     9434.390652
#  12     9619.438377
#  13    10416.536590
#  14    10790.328720
#  15    11018.955850
#  16    11482.891530
#  17    12974.806620
#  18    15080.283450
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
(xtrain, xtest, ytrain, ytest) = train_test_split(x, y, test_size=0.25, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
reg.predict(df[['year']])
# Out:
# array([ -467.51172529,   396.70072467,  1260.91317464,  2125.1256246 ,
#         2989.33807457,  3853.55052453,  4717.7629745 ,  5581.97542446,
#         6446.18787443,  7310.40032439,  8174.61277436,  9038.82522432,
#         9903.03767429, 10767.25012425, 11631.46257422, 12495.67502418,
#        13359.88747415, 14224.09992412, 15088.31237408, 15952.52482405,
#        16816.73727401, 17680.94972398, 18545.16217394, 19409.37462391,
#        20273.58707387, 21137.79952384, 22002.0119738 , 22866.22442377,
#        23730.43687373, 24594.6493237 , 25458.86177366, 26323.07422363,
#        27187.28667359, 28051.49912356, 28915.71157353, 29779.92402349,
#        30644.13647346, 31508.34892342, 32372.56137339, 33236.77382335,
#        34100.98627332, 34965.19872328, 35829.41117325, 36693.62362321,
#        37557.83607318, 38422.04852314, 39286.26097311])

# %%
reg.predict([[2020]])
# Out:
# array([42743.11077297])

# %%
df['predicted'] = reg.predict(df[['year']])

# %%
df
# Out:
#     year  per capita income (US$)     predicted
# 0   1970              3399.299037   -467.511725
# 1   1971              3768.297935    396.700725
# 2   1972              4251.175484   1260.913175
# 3   1973              4804.463248   2125.125625
# 4   1974              5576.514583   2989.338075
# 5   1975              5998.144346   3853.550525
# 6   1976              7062.131392   4717.762974
# 7   1977              7100.126170   5581.975424
# 8   1978              7247.967035   6446.187874
# 9   1979              7602.912681   7310.400324
# 10  1980              8355.968120   8174.612774
# 11  1981              9434.390652   9038.825224
# 12  1982              9619.438377   9903.037674
# 13  1983             10416.536590  10767.250124
# 14  1984             10790.328720  11631.462574
# 15  1985             11018.955850  12495.675024
# 16  1986             11482.891530  13359.887474
# 17  1987             12974.806620  14224.099924
# 18  1988             15080.283450  15088.312374
# ...

# %%
df.to_csv('canada_per_capita_income.csv', index=False)

# %%
plt.scatter(df['year'], df['per capita income (US$)'], marker='.', color='black')
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.title('canada_per_capita_income')
plt.plot(df.year, reg.predict(df[['year']]))

# %%
reg.coef_
# Out:
# array([864.21244997])

# %%
reg.intercept_
# Out:
# -1702966.0381569427

# %%
reg.predict([[2022]])
# Out:
# array([44471.5356729])
